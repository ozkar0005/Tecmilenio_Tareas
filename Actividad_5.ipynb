# %% [markdown]
# <a href="https://colab.research.google.com/github/ozkar0005/Tecmilenio_Tareas/blob/FUNDAMENTOS_Y_APLICACIONES_DE_IA/Actividad_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ## **UNIVERSIDAD TECMILENIO**
#
# ####**MASTER EN INTELIGENCIA ARTIFICIAL**
#
# ####**FUNDAMENTOS Y APLICACIONES DE INTELIGENCIA ARTIFICIAL (ACTIVIDAD 5)**
#
# * **Nombre del alumno:**  _Oscar Acosta Lira_
# * **Nnombre de la actividad:**  _Elementos básicos en la programación para inteligencia artificial_
# * **Nombre del docente:**  _M. en C Luis Ariel Vázquez Piña_
# * **Fecha de entrega:**  _20-02-2026_

# %% [markdown]
# ---
#
#
# * _Declaro que el presente trabajo se realizo sin el uso de herramientas de Inteligencia Artificial de tipo generativa_

# %% [markdown]
# ---
#
#
# ## **Parte 1**

# %% [markdown]
# Utilizando la herramienta Júpiter Notebook programa lo siguiente:
#
# * Escribe una lista que contenga un mínimo de cinco elementos.

# %%
lista = ["1", 2, 3.0, [4,4], "cinco"]
print(lista)
# Out:
# ['1', 2, 3.0, [4, 4], 'cinco']

# %% [markdown]
# * Agrega un nuevo elemento en el índice 2

# %%
lista.insert(2,"elemento agregado")
print(lista)
# Out:
# ['1', 2, 'elemento agregado', 3.0, [4, 4], 'cinco']

# %% [markdown]
# * Agrega un elemento al final de la lista

# %%
lista.append("elemento final")
print(lista)
# Out:
# ['1', 2, 'elemento agregado', 3.0, [4, 4], 'cinco', 'elemento final']

# %% [markdown]
# * Escribe una cadena de caracteres que contenga tres palabras

# %%
cadena = "Oscar Acosta Lira"
print(cadena)
# Out:
# Oscar Acosta Lira

# %% [markdown]
# * Cuenta los caracteres de la cadena generada

# %%
numero_caracteres = len(cadena)
print(numero_caracteres)
# Out:
# 17

# %% [markdown]
# * Guarda la cadena resultante toda en mayúsculas en una nueva variable

# %%
cadena_mayusculas = cadena.upper()
print(cadena_mayusculas)
# Out:
# OSCAR ACOSTA LIRA

# %% [markdown]
# * Escribe un diccionario que contenga al menos cuatro elementos y cuyos índices coincidan con las primeras letras del alfabeto

# %%
diccionario = {"a":"1","b":2,"c":3.0,"d":[4,4]}
print(diccionario)
# Out:
# {'a': '1', 'b': 2, 'c': 3.0, 'd': [4, 4]}

# %% [markdown]
# * Agrega un nuevo elemento al diccionario

# %%
diccionario["e"] = "cinco"
print(diccionario)
# Out:
# {'a': '1', 'b': 2, 'c': 3.0, 'd': [4, 4], 'e': 'cinco'}

# %% [markdown]
# * Elimina el elemento del índice “c”

# %%
del diccionario["c"]
print(diccionario)
# Out:
# {'a': '1', 'b': 2, 'd': [4, 4], 'e': 'cinco'}

# %% [markdown]
# * Cuenta los elementos que componen el diccionario después de completadas las operaciones anteriores

# %%
numero_elementos = len(diccionario)
print(numero_elementos)
# Out:
# 4

# %% [markdown]
# ---
#
#
# ## **Parte 2**

# %% [markdown]
# * Una sala de cine cobra diferentes precios de entrada según la edad de la persona. Si una persona es menor de 3 años, la entrada es gratuita; si tienen entre 3 y 12, el boleto es de 10 pesos; y si son mayores de 12 años, el boleto cuesta 15 pesos. Escribe un bucle en el que se solicite a los usuarios su edad y despliegue el costo de la entrada

# %%
print("Precios de entrada")
edad = ""
# se evita que ingresen valores incorrectos
while (isinstance(edad, int) != True):
  edad = input("Ingrese su edad: ")
# se convierte el valor ingresado para realizar la comparación
  if edad.isdigit():
    edad = int(edad)
    if edad < 3:
      print("La entrada es gratuita")
      break
    if edad >= 3 and edad <= 12:
      print("El precio de entrada es de $10")
      break
    if edad > 12:
      print("El precio de entrada es de $15")
      break
  else:
    print("Ingrese una edad válida")
# Out:
# Precios de entrada
# Ingrese su edad: 10
# El precio de entrada es de $10
